# %% [markdown]
# ## GENRE CLASSIFIER

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
# load data

dataset_path = "data_10.json"

def load_data(dataset_path):
    with open(dataset_path, "r") as fp: # r for reading
        data = json.load(fp)
    
    # convert lists into numpy array because labels and mfccs are lists
    inputs = np.array(data["mfcc"])
    targets = np.array(data["labels"])
    
    return inputs, targets

if __name__ == "__main__":
    
    # load data
    
    # inputs is a 3D array (segment #, mfcc 1 = interval, mfcc 2 = value)
    inputs, targets = load_data(dataset_path)
    
    # split data into training and test set with sklearn
    
    inputs_train, inputs_test, targets_train, targets_test = train_test_split(inputs, 
                                                                              targets, 
                                                                              test_size = 0.3) # test set = 30%
    #return x_train, x_test, y_train, y_test

    # build the network architecture with keras
    model = keras.Sequential([
         
        # input layer
        keras.layers.Flatten(input_shape = (inputs.shape[1], inputs.shape[2])), # turns 2D array into a 1D array
        
        # 1st. hidden layer
        keras.layers.Dense(512, activation = "relu"), # ReLU activation function
         
         # 2nd. hidden layer
        keras.layers.Dense(256, activation = "relu"), # ReLU activation function
         
         # 3rd. hidden layer
        keras.layers.Dense(64, activation = "relu"), # ReLU activation function
         
        # output layers
        keras.layers.Dense(10, activation = "softmax") # 10 categories, softmax normalizes result to 0 - 1
    ])
    
    # compile
    optimizer = keras.optimizers.Adam(learning_rate = 0.0001) # Adam = variation of SGD
    model.compile(optimizer = optimizer, 
                  loss = "sparse_categorical_crossentropy", # loss type depends on the type of task
                  metrics = ["accuracy"])
    
    model.summary()
    
    # train network
    model.fit(inputs_train, targets_train, 
              validation_data = (inputs_test, targets_test),
             epochs = 50,
             batch_size = 32) # batch_size defines the step at which the stochastic GD is performed
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 1690)              0
#
#  dense_4 (Dense)             (None, 512)               865792
#
#  dense_5 (Dense)             (None, 256)               131328
#
#  dense_6 (Dense)             (None, 64)                16448
#
#  dense_7 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 1,014,218
# Trainable params: 1,014,218
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 22/22 [==============================] - 1s 26ms/step - loss: 19.5668 - accuracy: 0.2260 - val_loss: 11.4377 - val_accuracy: 0.3633
# Epoch 2/50
# 22/22 [==============================] - 0s 13ms/step - loss: 6.9197 - accuracy: 0.4950 - val_loss: 8.3375 - val_accuracy: 0.4667
# Epoch 3/50
# 22/22 [==============================] - 0s 13ms/step - loss: 3.2667 - accuracy: 0.6395 - val_loss: 6.1730 - val_accuracy: 0.5500
# Epoch 4/50
# 22/22 [==============================] - 0s 13ms/step - loss: 1.6348 - accuracy: 0.7883 - val_loss: 6.1609 - val_accuracy: 0.5267
# Epoch 5/50
# 22/22 [==============================] - 0s 13ms/step - loss: 1.2232 - accuracy: 0.8183 - val_loss: 5.9277 - val_accuracy: 0.5667
# Epoch 6/50
# 22/22 [==============================] - 0s 15ms/step - loss: 0.6728 - accuracy: 0.8655 - val_loss: 6.1096 - val_accuracy: 0.5533
# Epoch 7/50
# 22/22 [==============================] - 0s 15ms/step - loss: 0.5271 - accuracy: 0.9041 - val_loss: 5.2486 - val_accuracy: 0.6133
# Epoch 8/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.3166 - accuracy: 0.9371 - val_loss: 5.2769 - val_accuracy: 0.5767
# Epoch 9/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.1805 - accuracy: 0.9499 - val_loss: 5.9452 - val_accuracy: 0.6033
# Epoch 10/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.1979 - accuracy: 0.9642 - val_loss: 5.1044 - val_accuracy: 0.6033
# Epoch 11/50
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0709 - accuracy: 0.9757 - val_loss: 5.0787 - val_accuracy: 0.6167
# Epoch 12/50
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0467 - accuracy: 0.9843 - val_loss: 5.0035 - val_accuracy: 0.6233
# Epoch 13/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0224 - accuracy: 0.9943 - val_loss: 5.0220 - val_accuracy: 0.6100
# Epoch 14/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 5.0677 - val_accuracy: 0.6333
# Epoch 15/50
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 4.9326 - val_accuracy: 0.6267
# Epoch 16/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 4.9044 - val_accuracy: 0.6233
# Epoch 17/50
# 22/22 [==============================] - 0s 12ms/step - loss: 9.5971e-04 - accuracy: 1.0000 - val_loss: 4.9056 - val_accuracy: 0.6267
# Epoch 18/50
# 22/22 [==============================] - 0s 13ms/step - loss: 8.7102e-04 - accuracy: 1.0000 - val_loss: 4.9032 - val_accuracy: 0.6267
# Epoch 19/50
# 22/22 [==============================] - 0s 12ms/step - loss: 8.0345e-04 - accuracy: 1.0000 - val_loss: 4.8972 - val_accuracy: 0.6267
# Epoch 20/50
# 22/22 [==============================] - 0s 13ms/step - loss: 7.4726e-04 - accuracy: 1.0000 - val_loss: 4.8966 - val_accuracy: 0.6267
# Epoch 21/50
# 22/22 [==============================] - 0s 13ms/step - loss: 6.9902e-04 - accuracy: 1.0000 - val_loss: 4.8950 - val_accuracy: 0.6267
# Epoch 22/50
# 22/22 [==============================] - 0s 13ms/step - loss: 6.6022e-04 - accuracy: 1.0000 - val_loss: 4.8901 - val_accuracy: 0.6267
# Epoch 23/50
# 22/22 [==============================] - 0s 13ms/step - loss: 6.2227e-04 - accuracy: 1.0000 - val_loss: 4.8862 - val_accuracy: 0.6267
# Epoch 24/50
# 22/22 [==============================] - 0s 12ms/step - loss: 5.9336e-04 - accuracy: 1.0000 - val_loss: 4.8843 - val_accuracy: 0.6267
# Epoch 25/50
# 22/22 [==============================] - 0s 12ms/step - loss: 5.6586e-04 - accuracy: 1.0000 - val_loss: 4.8826 - val_accuracy: 0.6300
# Epoch 26/50
# 22/22 [==============================] - 0s 14ms/step - loss: 5.4106e-04 - accuracy: 1.0000 - val_loss: 4.8795 - val_accuracy: 0.6333
# Epoch 27/50
# 22/22 [==============================] - 0s 13ms/step - loss: 5.1696e-04 - accuracy: 1.0000 - val_loss: 4.8760 - val_accuracy: 0.6333
# Epoch 28/50
# 22/22 [==============================] - 0s 13ms/step - loss: 4.9788e-04 - accuracy: 1.0000 - val_loss: 4.8708 - val_accuracy: 0.6333
# Epoch 29/50
# 22/22 [==============================] - 0s 12ms/step - loss: 4.7932e-04 - accuracy: 1.0000 - val_loss: 4.8687 - val_accuracy: 0.6333
# Epoch 30/50
# 22/22 [==============================] - 0s 13ms/step - loss: 4.6073e-04 - accuracy: 1.0000 - val_loss: 4.8693 - val_accuracy: 0.6367
# Epoch 31/50
# 22/22 [==============================] - 0s 13ms/step - loss: 4.4492e-04 - accuracy: 1.0000 - val_loss: 4.8652 - val_accuracy: 0.6367
# Epoch 32/50
# 22/22 [==============================] - 0s 13ms/step - loss: 4.2859e-04 - accuracy: 1.0000 - val_loss: 4.8629 - val_accuracy: 0.6333
# Epoch 33/50
# 22/22 [==============================] - 0s 13ms/step - loss: 4.1562e-04 - accuracy: 1.0000 - val_loss: 4.8616 - val_accuracy: 0.6333
# Epoch 34/50
# 22/22 [==============================] - 0s 13ms/step - loss: 4.0207e-04 - accuracy: 1.0000 - val_loss: 4.8605 - val_accuracy: 0.6333
# Epoch 35/50
# 22/22 [==============================] - 0s 13ms/step - loss: 3.8960e-04 - accuracy: 1.0000 - val_loss: 4.8573 - val_accuracy: 0.6333
# Epoch 36/50
# 22/22 [==============================] - 0s 14ms/step - loss: 3.7689e-04 - accuracy: 1.0000 - val_loss: 4.8555 - val_accuracy: 0.6367
# Epoch 37/50
# 22/22 [==============================] - 0s 14ms/step - loss: 3.6604e-04 - accuracy: 1.0000 - val_loss: 4.8525 - val_accuracy: 0.6367
# Epoch 38/50
# 22/22 [==============================] - 0s 15ms/step - loss: 3.5663e-04 - accuracy: 1.0000 - val_loss: 4.8521 - val_accuracy: 0.6367
# Epoch 39/50
# 22/22 [==============================] - 0s 16ms/step - loss: 3.4617e-04 - accuracy: 1.0000 - val_loss: 4.8514 - val_accuracy: 0.6367
# Epoch 40/50
# 22/22 [==============================] - 0s 12ms/step - loss: 3.3591e-04 - accuracy: 1.0000 - val_loss: 4.8460 - val_accuracy: 0.6367
# Epoch 41/50
# 22/22 [==============================] - 0s 13ms/step - loss: 3.2901e-04 - accuracy: 1.0000 - val_loss: 4.8478 - val_accuracy: 0.6333
# Epoch 42/50
# 22/22 [==============================] - 0s 12ms/step - loss: 3.1895e-04 - accuracy: 1.0000 - val_loss: 4.8463 - val_accuracy: 0.6367
# Epoch 43/50
# 22/22 [==============================] - 0s 14ms/step - loss: 3.1062e-04 - accuracy: 1.0000 - val_loss: 4.8421 - val_accuracy: 0.6333
# Epoch 44/50
# 22/22 [==============================] - 0s 12ms/step - loss: 3.0315e-04 - accuracy: 1.0000 - val_loss: 4.8427 - val_accuracy: 0.6333
# Epoch 45/50
# 22/22 [==============================] - 0s 14ms/step - loss: 2.9526e-04 - accuracy: 1.0000 - val_loss: 4.8406 - val_accuracy: 0.6333
# Epoch 46/50
# 22/22 [==============================] - 0s 14ms/step - loss: 2.8906e-04 - accuracy: 1.0000 - val_loss: 4.8383 - val_accuracy: 0.6367
# Epoch 47/50
# 22/22 [==============================] - 0s 12ms/step - loss: 2.8164e-04 - accuracy: 1.0000 - val_loss: 4.8369 - val_accuracy: 0.6367
# Epoch 48/50
# 22/22 [==============================] - 0s 14ms/step - loss: 2.7523e-04 - accuracy: 1.0000 - val_loss: 4.8356 - val_accuracy: 0.6367
# Epoch 49/50
# 22/22 [==============================] - 0s 13ms/step - loss: 2.6913e-04 - accuracy: 1.0000 - val_loss: 4.8345 - val_accuracy: 0.6367
# Epoch 50/50
# 22/22 [==============================] - 0s 13ms/step - loss: 2.6244e-04 - accuracy: 1.0000 - val_loss: 4.8331 - val_accuracy: 0.6367
